# %% [markdown]
# # PEEK in PyTorch

# %% [markdown]
# ## Pretrained VGG Image Classifier Demo

# %% [markdown]
# ### Run Inference and Save Feature Maps

# %%
from peek.functions import VGG16FeatureExtractor

# replace 'image_samples/imagenet_valset' with a folder of images or video frames
image_folder = 'image_samples/imagenet_valset'

# extract and save feaures from a VGG classifier pretrained on ImageNet
feature_extractor = VGG16FeatureExtractor()
feature_extractor.eval()
feature_extractor.save_features(image_folder)
# Out:
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000193.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000195.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000205.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000206.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000207.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000208.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000209.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000210.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000211.pkl
# Saved all features to feature_maps/imagenet_valset/ILSVRC2012_val_00000212.pkl

# %% [markdown]
# ### Plot PEEK Maps in Notebook

# %%
import glob
from peek.functions import plot_PEEK

# gather the filepaths to the input images
image_folder = 'image_samples/imagenet_valset'
image_filepaths = sorted(glob.glob(f'{image_folder}/*'))

# plot PEEK maps of the selected modules in YOLOv5 and display them in the notebook
plot_PEEK(modules=[0, 3, 6, 9, 12],
          frame_paths=image_filepaths,
          feature_folder='feature_maps/imagenet_valset',
          verbose=False)

# %% [markdown]
# ### Save Plotted PEEK Maps

# %%
import glob
from peek.functions import plot_PEEK

# gather the filepaths to the input images
image_folder = 'image_samples/imagenet_valset'
image_filepaths = sorted(glob.glob(f'{image_folder}/*'))

# plot PEEK maps of the selected modules in YOLOv5 and display them in the notebook
plot_PEEK(modules=[0, 3, 6, 9, 12],
          frame_paths=image_filepaths,
          save_path='plots/imagenet',
          feature_folder='feature_maps/imagenet_valset',
          verbose=True)
# Out:
# Finished with frame image_samples/imagenet_valset/ILSVRC2012_val_00000193.JPEG.
# Saving figure to plots/imagenet/ILSVRC2012_val_00000193.JPEG
# Finished with frame image_samples/imagenet_valset/ILSVRC2012_val_00000195.JPEG.
# Saving figure to plots/imagenet/ILSVRC2012_val_00000195.JPEG
# Finished with frame image_samples/imagenet_valset/ILSVRC2012_val_00000205.JPEG.
# Saving figure to plots/imagenet/ILSVRC2012_val_00000205.JPEG
# Finished with frame image_samples/imagenet_valset/ILSVRC2012_val_00000206.JPEG.
# Saving figure to plots/imagenet/ILSVRC2012_val_00000206.JPEG
# Finished with frame image_samples/imagenet_valset/ILSVRC2012_val_00000207.JPEG.
# Saving figure to plots/imagenet/ILSVRC2012_val_00000207.JPEG
# Finished with frame image_samples/imagenet_valset/ILSVRC2012_val_00000208.JPEG.
# Saving figure to plots/imagenet/ILSVRC2012_val_00000208.JPEG
# Finished with frame image_samples/imagenet_valset/ILSVRC2012_val_00000209.JPEG.
# ...
